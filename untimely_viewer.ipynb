# %%
from unTimely_Catalog_tools import unTimelyCatalogExplorer
import tempfile

# %%
ucx = unTimelyCatalogExplorer(directory=tempfile.gettempdir(), cache=True, show_progress=True, timeout=300, suppress_console_output=False,
                              # catalog_base_url='http://unwise.me/data/neo7/untimely-catalog/',
                            catalog_base_url='/home/kangzihan/project_unTimely_light_curve/untimely-catalog/',
                            catalog_index_file='untimely_index-neo7.fits')

result_table = ucx.search_by_coordinates(0.16662 , -1.1911253
, box_size=100, cone_radius=None, show_result_table_in_browser=False,
                                         save_result_table=True, result_table_format='ascii.ipac', result_table_extension='dat')
# Out:
# Scanning catalog index file ...
# Scanning individual catalog files ...
# ./000/0000m016/0000m016_w2_e000.cat.fits.gz
# ./000/0000m016/0000m016_w1_e001.cat.fits.gz
# ./000/0000m016/0000m016_w2_e001.cat.fits.gz
# ./000/0000m016/0000m016_w1_e002.cat.fits.gz
# ./000/0000m016/0000m016_w2_e002.cat.fits.gz
# ./000/0000m016/0000m016_w1_e003.cat.fits.gz
# ./000/0000m016/0000m016_w2_e003.cat.fits.gz
# ./000/0000m016/0000m016_w1_e004.cat.fits.gz
# ./000/0000m016/0000m016_w2_e004.cat.fits.gz
# ./000/0000m016/0000m016_w1_e005.cat.fits.gz
# ./000/0000m016/0000m016_w2_e005.cat.fits.gz
# ./000/0000m016/0000m016_w1_e006.cat.fits.gz
# ./000/0000m016/0000m016_w2_e006.cat.fits.gz
# ./000/0000m016/0000m016_w1_e007.cat.fits.gz
# ./000/0000m016/0000m016_w2_e007.cat.fits.gz
# ./000/0000m016/0000m016_w1_e008.cat.fits.gz
# ./000/0000m016/0000m016_w2_e008.cat.fits.gz
# ./000/0000m016/0000m016_w1_e009.cat.fits.gz
# ./000/0000m016/0000m016_w2_e009.cat.fits.gz
# ./000/0000m016/0000m016_w1_e010.cat.fits.gz
# ./000/0000m016/0000m016_w2_e010.cat.fits.gz
# ./000/0000m016/0000m016_w1_e011.cat.fits.gz
# ./000/0000m016/0000m016_w2_e011.cat.fits.gz
# ./000/0000m016/0000m016_w1_e012.cat.fits.gz
# ./000/0000m016/0000m016_w2_e012.cat.fits.gz
# ./000/0000m016/0000m016_w1_e013.cat.fits.gz
# ./000/0000m016/0000m016_w2_e013.cat.fits.gz
# ./000/0000m016/0000m016_w1_e014.cat.fits.gz
# ./000/0000m016/0000m016_w2_e014.cat.fits.gz
# ./000/0000m016/0000m016_w1_e015.cat.fits.gz
# ./000/0000m016/0000m016_w2_e015.cat.fits.gz
# ./000/0000m016/0000m016_w1_e016.cat.fits.gz
# ./000/0000m016/0000m016_w2_e016.cat.fits.gz

# %%
ucx.create_finder_charts(overlays=True, overlay_color='green', overlay_labels=False, overlay_label_color='red',
                         image_contrast=5, open_file=False, file_format='pdf')
# Out:
# Creating finder charts ...

# %%
print(tempfile.gettempdir())
# Out:
# /tmp

# %%
ucx.create_light_curves(photometry_radius=2, yticks=None, open_file=False, file_format='png', overplot_l1b_phot=True, bin_l1b_phot=True)
# Out:
# Creating light curves ...
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kangzihan/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
