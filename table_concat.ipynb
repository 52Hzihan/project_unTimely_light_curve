# %%
import pandas as pd
import glob
import os
import time

def one_turn_concat(table_list):
    start = time.time()
    result_table_list = []
    while len(table_list) > 1:
        sub_table1 = table_list.pop()
        sub_table2 = table_list.pop()
        result_table_list.append(pd.concat([sub_table1,sub_table2]))
    if len(table_list) == 1:
        result_table_list.append(table_list.pop())
    result_table_list.reverse()
    return result_table_list

# %%
first_layer_names = glob.glob('[0-9][0-9][0-9]',root_dir='./mached_catalog')
first_layer_names.sort()
count=0
para_tables = []
for name in first_layer_names:

    if count>=9200:
        print("count=%d, break"%count)
        break

    second_layer_names = glob.glob('[0-9][0-9][0-9][0-9]*',
                                root_dir='./mached_catalog/'+name)
    second_layer_names.sort()
    for long_name in second_layer_names:
        # band='w2'        
        # if True == os.path.isfile('./mached_catalog/'+name+'/'+long_name+'/'+long_name+'_'+ band +'_new_features.csv'):
        if True == os.path.isfile('./mached_catalog/'+name+'/'+long_name+'/'+long_name+'_corelation.csv'):

            # if count >= 9233:
            #     table = pd.read_csv('./mached_catalog/'+name+'/'+long_name+'/'+long_name+'_'+ band +'_new_features.csv')
            #     para_tables.append(table)

            # table = pd.read_csv('./mached_catalog/'+name+'/'+long_name+'/'+long_name+'_'+ band +'_new_features.csv')
            # para_tables.append(table)
            table = pd.read_csv('./mached_catalog/'+name+'/'+long_name+'/'+long_name+'_corelation.csv')
            para_tables.append(table)

            count+=1
            print("%f percent finished,count=%d"%(count/182.21, count))
            print(name)
# Out:
# 0.005488 percent finished,count=1
# 000
# 0.010976 percent finished,count=2
# 000
# 0.016465 percent finished,count=3
# 000
# 0.021953 percent finished,count=4
# 000
# 0.027441 percent finished,count=5
# 000
# 0.032929 percent finished,count=6
# 000
# 0.038417 percent finished,count=7
# 000
# 0.043905 percent finished,count=8
# 000
# 0.049394 percent finished,count=9
# 000
# 0.054882 percent finished,count=10
# 000
# 0.060370 percent finished,count=11
# 000
# 0.065858 percent finished,count=12
# 000
# 0.071346 percent finished,count=13
# 000
# 0.076834 percent finished,count=14
# 000
# 0.082323 percent finished,count=15
# 000
# 0.087811 percent finished,count=16
# 000
# 0.093299 percent finished,count=17
# 000
# 0.098787 percent finished,count=18
# 000
# 0.104275 percent finished,count=19
# 000
# 0.109763 percent finished,count=20
# 000
# 0.115252 percent finished,count=21
# 000
# 0.120740 percent finished,count=22
# 000
# 0.126228 percent finished,count=23
# 000
# 0.131716 percent finished,count=24
# 000
# 0.137204 percent finished,count=25
# 000
# 0.142692 percent finished,count=26
# 000
# 0.148181 percent finished,count=27
# 000
# 0.153669 percent finished,count=28
# 000
# 0.159157 percent finished,count=29
# 000
# 0.164645 percent finished,count=30
# 000
# 0.170133 percent finished,count=31
# 000
# 0.175622 percent finished,count=32
# 000
# 0.181110 percent finished,count=33
# 000
# 0.186598 percent finished,count=34
# 000
# 0.192086 percent finished,count=35
# 000
# 0.197574 percent finished,count=36
# 000
# 0.203062 percent finished,count=37
# 000
# 0.208551 percent finished,count=38
# 000
# 0.214039 percent finished,count=39
# 000
# 0.219527 percent finished,count=40
# 000
# 0.225015 percent finished,count=41
# 000
# 0.230503 percent finished,count=42
# 000
# 0.235991 percent finished,count=43
# 000
# 0.241480 percent finished,count=44
# 000
# 0.246968 percent finished,count=45
# 000
# 0.252456 percent finished,count=46
# 000
# 0.257944 percent finished,count=47
# 000
# 0.263432 percent finished,count=48
# 000
# 0.268920 percent finished,count=49
# 000
# 0.274409 percent finished,count=50
# 000
# 0.279897 percent finished,count=51
# 000
# 0.285385 percent finished,count=52
# 000
# 0.290873 percent finished,count=53
# 000
# 0.296361 percent finished,count=54
# 000
# 0.301850 percent finished,count=55
# 000
# 0.307338 percent finished,count=56
# 000
# 0.312826 percent finished,count=57
# 000
# 0.318314 percent finished,count=58
# 000
# 0.323802 percent finished,count=59
# 000
# 0.329290 percent finished,count=60
# 000
# 0.334779 percent finished,count=61
# 000
# 0.340267 percent finished,count=62
# 000
# 0.345755 percent finished,count=63
# 000
# 0.351243 percent finished,count=64
# 000
# 0.356731 percent finished,count=65
# 000
# 0.362219 percent finished,count=66
# 000
# 0.367708 percent finished,count=67
# 000
# 0.373196 percent finished,count=68
# 000
# 0.378684 percent finished,count=69
# 000
# 0.384172 percent finished,count=70
# 000
# 0.389660 percent finished,count=71
# 000
# 0.395148 percent finished,count=72
# 000
# 0.400637 percent finished,count=73
# 000
# 0.406125 percent finished,count=74
# 000
# 0.411613 percent finished,count=75
# 000
# 0.417101 percent finished,count=76
# 000
# 0.422589 percent finished,count=77
# 000
# 0.428077 percent finished,count=78
# 000
# 0.433566 percent finished,count=79
# 000
# 0.439054 percent finished,count=80
# 000
# 0.444542 percent finished,count=81
# 000
# 0.450030 percent finished,count=82
# 000
# 0.455518 percent finished,count=83
# 000
# 0.461007 percent finished,count=84
# 000
# 0.466495 percent finished,count=85
# 000
# 0.471983 percent finished,count=86
# 000
# 0.477471 percent finished,count=87
# 000
# 0.482959 percent finished,count=88
# 000
# 0.488447 percent finished,count=89
# 000
# 0.493936 percent finished,count=90
# 000
# 0.499424 percent finished,count=91
# 000
# 0.504912 percent finished,count=92
# 000
# 0.510400 percent finished,count=93
# 000
# 0.515888 percent finished,count=94
# 000
# 0.521376 percent finished,count=95
# 000
# 0.526865 percent finished,count=96
# 000
# 0.532353 percent finished,count=97
# 000
# 0.537841 percent finished,count=98
# 000
# 0.543329 percent finished,count=99
# 000
# 0.548817 percent finished,count=100
# 000
# 0.554305 percent finished,count=101
# 000
# 0.559794 percent finished,count=102
# 000
# 0.565282 percent finished,count=103
# 000
# 0.570770 percent finished,count=104
# 000
# 0.576258 percent finished,count=105
# 000
# 0.581746 percent finished,count=106
# 000
# 0.587235 percent finished,count=107
# 000
# 0.592723 percent finished,count=108
# 000
# 0.598211 percent finished,count=109
# 000
# 0.603699 percent finished,count=110
# 000
# 0.609187 percent finished,count=111
# 000
# 0.614675 percent finished,count=112
# 000
# 0.620164 percent finished,count=113
# 000
# 0.625652 percent finished,count=114
# 000
# 0.631140 percent finished,count=115
# 000
# 0.636628 percent finished,count=116
# 000
# 0.642116 percent finished,count=117
# 000
# 0.647604 percent finished,count=118
# 000
# 0.653093 percent finished,count=119
# 001
# 0.658581 percent finished,count=120
# 001
# 0.664069 percent finished,count=121
# 001
# 0.669557 percent finished,count=122
# 001
# 0.675045 percent finished,count=123
# 001
# 0.680533 percent finished,count=124
# 001
# 0.686022 percent finished,count=125
# 001
# 0.691510 percent finished,count=126
# 001
# 0.696998 percent finished,count=127
# 001
# 0.702486 percent finished,count=128
# 001
# 0.707974 percent finished,count=129
# 001
# 0.713462 percent finished,count=130
# 001
# 0.718951 percent finished,count=131
# 001
# 0.724439 percent finished,count=132
# 001
# 0.729927 percent finished,count=133
# 001
# 0.735415 percent finished,count=134
# 001
# 0.740903 percent finished,count=135
# 001
# 0.746392 percent finished,count=136
# 001
# 0.751880 percent finished,count=137
# 001
# 0.757368 percent finished,count=138
# 001
# 0.762856 percent finished,count=139
# 001
# 0.768344 percent finished,count=140
# 001
# 0.773832 percent finished,count=141
# 001
# 0.779321 percent finished,count=142
# 001
# 0.784809 percent finished,count=143
# 001
# 0.790297 percent finished,count=144
# 001
# 0.795785 percent finished,count=145
# 001
# 0.801273 percent finished,count=146
# 001
# 0.806761 percent finished,count=147
# 001
# 0.812250 percent finished,count=148
# 001
# 0.817738 percent finished,count=149
# 001
# 0.823226 percent finished,count=150
# 001
# 0.828714 percent finished,count=151
# 001
# 0.834202 percent finished,count=152
# 001
# 0.839690 percent finished,count=153
# 001
# 0.845179 percent finished,count=154
# 001
# 0.850667 percent finished,count=155
# 001
# 0.856155 percent finished,count=156
# 001
# 0.861643 percent finished,count=157
# 001
# 0.867131 percent finished,count=158
# 001
# 0.872620 percent finished,count=159
# 001
# 0.878108 percent finished,count=160
# 001
# 0.883596 percent finished,count=161
# 001
# 0.889084 percent finished,count=162
# 001
# 0.894572 percent finished,count=163
# 001
# 0.900060 percent finished,count=164
# 001
# 0.905549 percent finished,count=165
# 001
# 0.911037 percent finished,count=166
# 001
# 0.916525 percent finished,count=167
# 001
# 0.922013 percent finished,count=168
# 001
# 0.927501 percent finished,count=169
# 001
# 0.932989 percent finished,count=170
# 001
# 0.938478 percent finished,count=171
# 001
# 0.943966 percent finished,count=172
# 001
# 0.949454 percent finished,count=173
# 001
# 0.954942 percent finished,count=174
# 002
# 0.960430 percent finished,count=175
# 002
# 0.965918 percent finished,count=176
# 002
# 0.971407 percent finished,count=177
# 002
# 0.976895 percent finished,count=178
# 002
# 0.982383 percent finished,count=179
# 002
# 0.987871 percent finished,count=180
# 002
# 0.993359 percent finished,count=181
# 002
# 0.998847 percent finished,count=182
# 002
# 1.004336 percent finished,count=183
# 002
# 1.009824 percent finished,count=184
# 002
# 1.015312 percent finished,count=185
# 002
# 1.020800 percent finished,count=186
# 002
# 1.026288 percent finished,count=187
# 002
# 1.031777 percent finished,count=188
# 002
# 1.037265 percent finished,count=189
# 002
# 1.042753 percent finished,count=190
# 002
# 1.048241 percent finished,count=191
# 002
# 1.053729 percent finished,count=192
# 002
# 1.059217 percent finished,count=193
# 002
# 1.064706 percent finished,count=194
# 002
# 1.070194 percent finished,count=195
# 002
# 1.075682 percent finished,count=196
# 002
# 1.081170 percent finished,count=197
# 002
# 1.086658 percent finished,count=198
# 003
# 1.092146 percent finished,count=199
# 003
# 1.097635 percent finished,count=200
# 003
# 1.103123 percent finished,count=201
# 003
# 1.108611 percent finished,count=202
# 003
# 1.114099 percent finished,count=203
# 003
# 1.119587 percent finished,count=204
# 003
# 1.125075 percent finished,count=205
# 003
# 1.130564 percent finished,count=206
# 003
# 1.136052 percent finished,count=207
# 003
# 1.141540 percent finished,count=208
# 003
# 1.147028 percent finished,count=209
# 003
# 1.152516 percent finished,count=210
# 003
# 1.158005 percent finished,count=211
# 003
# 1.163493 percent finished,count=212
# 003
# 1.168981 percent finished,count=213
# 003
# 1.174469 percent finished,count=214
# 003
# 1.179957 percent finished,count=215
# 003
# 1.185445 percent finished,count=216
# 003
# 1.190934 percent finished,count=217
# 003
# 1.196422 percent finished,count=218
# 003
# 1.201910 percent finished,count=219
# 003
# 1.207398 percent finished,count=220
# 003
# 1.212886 percent finished,count=221
# 003
# 1.218374 percent finished,count=222
# 003
# 1.223863 percent finished,count=223
# 003
# 1.229351 percent finished,count=224
# 003
# 1.234839 percent finished,count=225
# 003
# 1.240327 percent finished,count=226
# 003
# 1.245815 percent finished,count=227
# 003
# 1.251303 percent finished,count=228
# 003
# 1.256792 percent finished,count=229
# 003
# 1.262280 percent finished,count=230
# 003
# 1.267768 percent finished,count=231
# 003
# 1.273256 percent finished,count=232
# 003
# 1.278744 percent finished,count=233
# 003
# 1.284232 percent finished,count=234
# 003
# 1.289721 percent finished,count=235
# 003
# 1.295209 percent finished,count=236
# 003
# 1.300697 percent finished,count=237
# 003
# 1.306185 percent finished,count=238
# 003
# 1.311673 percent finished,count=239
# 003
# 1.317162 percent finished,count=240
# 003
# 1.322650 percent finished,count=241
# 003
# 1.328138 percent finished,count=242
# 003
# 1.333626 percent finished,count=243
# 003
# 1.339114 percent finished,count=244
# 003
# 1.344602 percent finished,count=245
# 003
# 1.350091 percent finished,count=246
# 003
# 1.355579 percent finished,count=247
# 003
# 1.361067 percent finished,count=248
# 003
# 1.366555 percent finished,count=249
# 003
# 1.372043 percent finished,count=250
# 003
# 1.377531 percent finished,count=251
# 003
# 1.383020 percent finished,count=252
# 003
# 1.388508 percent finished,count=253
# 003
# 1.393996 percent finished,count=254
# 003
# 1.399484 percent finished,count=255
# 003
# 1.404972 percent finished,count=256
# 003
# 1.410460 percent finished,count=257
# 003
# 1.415949 percent finished,count=258
# 003
# 1.421437 percent finished,count=259
# 003
# 1.426925 percent finished,count=260
# 003
# 1.432413 percent finished,count=261
# 003
# 1.437901 percent finished,count=262
# 003
# 1.443389 percent finished,count=263
# 003
# 1.448878 percent finished,count=264
# 003
# 1.454366 percent finished,count=265
# 004
# 1.459854 percent finished,count=266
# 004
# 1.465342 percent finished,count=267
# 004
# 1.470830 percent finished,count=268
# 004
# 1.476319 percent finished,count=269
# 004
# 1.481807 percent finished,count=270
# 004
# 1.487295 percent finished,count=271
# 004
# 1.492783 percent finished,count=272
# 004
# 1.498271 percent finished,count=273
# 004
# 1.503759 percent finished,count=274
# 004
# 1.509248 percent finished,count=275
# 004
# 1.514736 percent finished,count=276
# 004
# 1.520224 percent finished,count=277
# 004
# 1.525712 percent finished,count=278
# 004
# 1.531200 percent finished,count=279
# 004
# 1.536688 percent finished,count=280
# 004
# 1.542177 percent finished,count=281
# 004
# 1.547665 percent finished,count=282
# 004
# 1.553153 percent finished,count=283
# 004
# 1.558641 percent finished,count=284
# 004
# 1.564129 percent finished,count=285
# 004
# 1.569617 percent finished,count=286
# 004
# 1.575106 percent finished,count=287
# 004
# 1.580594 percent finished,count=288
# 004
# 1.586082 percent finished,count=289
# 004
# 1.591570 percent finished,count=290
# 004
# 1.597058 percent finished,count=291
# 004
# 1.602547 percent finished,count=292
# 004
# 1.608035 percent finished,count=293
# 004
# 1.613523 percent finished,count=294
# 004
# 1.619011 percent finished,count=295
# 004
# 1.624499 percent finished,count=296
# 004
# 1.629987 percent finished,count=297
# 004
# 1.635476 percent finished,count=298
# 004
# 1.640964 percent finished,count=299
# 004
# 1.646452 percent finished,count=300
# 004
# 1.651940 percent finished,count=301
# 004
# 1.657428 percent finished,count=302
# 004
# 1.662916 percent finished,count=303
# 004
# 1.668405 percent finished,count=304
# 004
# 1.673893 percent finished,count=305
# 004
# 1.679381 percent finished,count=306
# 004
# 1.684869 percent finished,count=307
# 004
# 1.690357 percent finished,count=308
# 004
# 1.695845 percent finished,count=309
# 004
# 1.701334 percent finished,count=310
# 004
# 1.706822 percent finished,count=311
# 004
# 1.712310 percent finished,count=312
# 004
# 1.717798 percent finished,count=313
# 004
# 1.723286 percent finished,count=314
# 004
# 1.728774 percent finished,count=315
# 004
# 1.734263 percent finished,count=316
# 004
# 1.739751 percent finished,count=317
# 004
# 1.745239 percent finished,count=318
# 004
# 1.750727 percent finished,count=319
# 004
# 1.756215 percent finished,count=320
# 005
# 1.761704 percent finished,count=321
# 005
# 1.767192 percent finished,count=322
# 005
# 1.772680 percent finished,count=323
# 005
# 1.778168 percent finished,count=324
# 005
# 1.783656 percent finished,count=325
# 005
# 1.789144 percent finished,count=326
# 005
# 1.794633 percent finished,count=327
# 005
# 1.800121 percent finished,count=328
# 005
# 1.805609 percent finished,count=329
# 005
# 1.811097 percent finished,count=330
# 005
# 1.816585 percent finished,count=331
# 005
# 1.822073 percent finished,count=332
# 005
# 1.827562 percent finished,count=333
# 005
# 1.833050 percent finished,count=334
# 005
# 1.838538 percent finished,count=335
# 005
# 1.844026 percent finished,count=336
# 005
# 1.849514 percent finished,count=337
# 005
# 1.855002 percent finished,count=338
# 005
# 1.860491 percent finished,count=339
# 005
# 1.865979 percent finished,count=340
# 005
# 1.871467 percent finished,count=341
# 005
# 1.876955 percent finished,count=342
# 005
# 1.882443 percent finished,count=343
# 005
# 1.887932 percent finished,count=344
# 005
# 1.893420 percent finished,count=345
# 005
# 1.898908 percent finished,count=346
# 005
# 1.904396 percent finished,count=347
# 005
# 1.909884 percent finished,count=348
# 005
# 1.915372 percent finished,count=349
# 005
# 1.920861 percent finished,count=350
# 005
# 1.926349 percent finished,count=351
# 005
# 1.931837 percent finished,count=352
# 005
# 1.937325 percent finished,count=353
# 005
# 1.942813 percent finished,count=354
# 006
# 1.948301 percent finished,count=355
# 006
# 1.953790 percent finished,count=356
# 006
# 1.959278 percent finished,count=357
# 006
# 1.964766 percent finished,count=358
# 006
# 1.970254 percent finished,count=359
# 006
# 1.975742 percent finished,count=360
# 006
# 1.981230 percent finished,count=361
# 006
# 1.986719 percent finished,count=362
# 006
# 1.992207 percent finished,count=363
# 006
# 1.997695 percent finished,count=364
# 006
# 2.003183 percent finished,count=365
# 006
# 2.008671 percent finished,count=366
# 006
# 2.014159 percent finished,count=367
# 006
# 2.019648 percent finished,count=368
# 006
# 2.025136 percent finished,count=369
# 006
# 2.030624 percent finished,count=370
# 006
# 2.036112 percent finished,count=371
# 006
# 2.041600 percent finished,count=372
# 006
# 2.047089 percent finished,count=373
# 006
# 2.052577 percent finished,count=374
# 006
# 2.058065 percent finished,count=375
# 006
# 2.063553 percent finished,count=376
# 006
# 2.069041 percent finished,count=377
# 006
# 2.074529 percent finished,count=378
# 006
# 2.080018 percent finished,count=379
# 006
# 2.085506 percent finished,count=380
# 006
# 2.090994 percent finished,count=381
# 006
# 2.096482 percent finished,count=382
# 006
# 2.101970 percent finished,count=383
# 006
# 2.107458 percent finished,count=384
# 006
# 2.112947 percent finished,count=385
# 006
# 2.118435 percent finished,count=386
# 006
# 2.123923 percent finished,count=387
# 006
# 2.129411 percent finished,count=388
# 006
# 2.134899 percent finished,count=389
# 006
# 2.140387 percent finished,count=390
# 006
# 2.145876 percent finished,count=391
# 006
# 2.151364 percent finished,count=392
# 006
# 2.156852 percent finished,count=393
# 006
# 2.162340 percent finished,count=394
# 006
# 2.167828 percent finished,count=395
# 006
# 2.173317 percent finished,count=396
# 006
# 2.178805 percent finished,count=397
# 006
# 2.184293 percent finished,count=398
# 006
# 2.189781 percent finished,count=399
# 006
# 2.195269 percent finished,count=400
# 006
# 2.200757 percent finished,count=401
# 006
# 2.206246 percent finished,count=402
# 006
# 2.211734 percent finished,count=403
# 006
# 2.217222 percent finished,count=404
# 006
# 2.222710 percent finished,count=405
# 006
# 2.228198 percent finished,count=406
# 006
# 2.233686 percent finished,count=407
# 006
# 2.239175 percent finished,count=408
# 006
# 2.244663 percent finished,count=409
# 006
# 2.250151 percent finished,count=410
# 006
# 2.255639 percent finished,count=411
# 006
# 2.261127 percent finished,count=412
# 006
# 2.266615 percent finished,count=413
# 006
# 2.272104 percent finished,count=414
# 006
# 2.277592 percent finished,count=415
# 006
# 2.283080 percent finished,count=416
# 006
# 2.288568 percent finished,count=417
# 007
# 2.294056 percent finished,count=418
# 007
# 2.299544 percent finished,count=419
# 007
# 2.305033 percent finished,count=420
# 007
# 2.310521 percent finished,count=421
# 007
# 2.316009 percent finished,count=422
# 007
# 2.321497 percent finished,count=423
# 007
# 2.326985 percent finished,count=424
# 007
# 2.332474 percent finished,count=425
# 007
# 2.337962 percent finished,count=426
# 007
# 2.343450 percent finished,count=427
# 007
# 2.348938 percent finished,count=428
# 007
# 2.354426 percent finished,count=429
# 007
# 2.359914 percent finished,count=430
# 007
# 2.365403 percent finished,count=431
# 007
# 2.370891 percent finished,count=432
# 007
# 2.376379 percent finished,count=433
# 007
# 2.381867 percent finished,count=434
# 007
# 2.387355 percent finished,count=435
# 007
# 2.392843 percent finished,count=436
# 007
# 2.398332 percent finished,count=437
# 007
# 2.403820 percent finished,count=438
# 007
# 2.409308 percent finished,count=439
# 007
# 2.414796 percent finished,count=440
# 007
# 2.420284 percent finished,count=441
# 007
# 2.425772 percent finished,count=442
# 007
# 2.431261 percent finished,count=443
# 007
# 2.436749 percent finished,count=444
# 007
# 2.442237 percent finished,count=445
# 007
# 2.447725 percent finished,count=446
# 007
# 2.453213 percent finished,count=447
# 007
# 2.458701 percent finished,count=448
# 007
# 2.464190 percent finished,count=449
# 007
# 2.469678 percent finished,count=450
# 007
# 2.475166 percent finished,count=451
# 007
# 2.480654 percent finished,count=452
# 007
# 2.486142 percent finished,count=453
# 007
# 2.491631 percent finished,count=454
# 007
# 2.497119 percent finished,count=455
# 007
# 2.502607 percent finished,count=456
# 007
# 2.508095 percent finished,count=457
# 007
# 2.513583 percent finished,count=458
# 007
# 2.519071 percent finished,count=459
# 007
# 2.524560 percent finished,count=460
# 007
# 2.530048 percent finished,count=461
# 007
# 2.535536 percent finished,count=462
# 007
# 2.541024 percent finished,count=463
# 007
# 2.546512 percent finished,count=464
# 007
# 2.552000 percent finished,count=465
# 007
# 2.557489 percent finished,count=466
# 007
# 2.562977 percent finished,count=467
# 007
# 2.568465 percent finished,count=468
# 007
# 2.573953 percent finished,count=469
# 007
# 2.579441 percent finished,count=470
# 008
# 2.584929 percent finished,count=471
# 008
# 2.590418 percent finished,count=472
# 008
# 2.595906 percent finished,count=473
# 008
# 2.601394 percent finished,count=474
# 008
# 2.606882 percent finished,count=475
# 008
# 2.612370 percent finished,count=476
# 008
# 2.617859 percent finished,count=477
# 008
# 2.623347 percent finished,count=478
# 008
# 2.628835 percent finished,count=479
# 008
# 2.634323 percent finished,count=480
# 008
# 2.639811 percent finished,count=481
# 008
# 2.645299 percent finished,count=482
# 008
# 2.650788 percent finished,count=483
# 008
# 2.656276 percent finished,count=484
# 008
# 2.661764 percent finished,count=485
# 008
# 2.667252 percent finished,count=486
# 008
# 2.672740 percent finished,count=487
# 008
# 2.678228 percent finished,count=488
# 008
# 2.683717 percent finished,count=489
# 008
# 2.689205 percent finished,count=490
# 008
# 2.694693 percent finished,count=491
# 008
# 2.700181 percent finished,count=492
# 008
# 2.705669 percent finished,count=493
# 008
# 2.711157 percent finished,count=494
# 008
# 2.716646 percent finished,count=495
# 008
# 2.722134 percent finished,count=496
# 008
# 2.727622 percent finished,count=497
# 008
# 2.733110 percent finished,count=498
# 008
# 2.738598 percent finished,count=499
# 008
# 2.744086 percent finished,count=500
# 008
# 2.749575 percent finished,count=501
# 008
# 2.755063 percent finished,count=502
# 008
# 2.760551 percent finished,count=503
# 008
# 2.766039 percent finished,count=504
# 008
# 2.771527 percent finished,count=505
# 008
# 2.777016 percent finished,count=506
# 008
# 2.782504 percent finished,count=507
# 008
# 2.787992 percent finished,count=508
# 009
# 2.793480 percent finished,count=509
# 009
# 2.798968 percent finished,count=510
# 009
# 2.804456 percent finished,count=511
# 009
# 2.809945 percent finished,count=512
# 009
# 2.815433 percent finished,count=513
# 009
# 2.820921 percent finished,count=514
# 009
# 2.826409 percent finished,count=515
# 009
# 2.831897 percent finished,count=516
# 009
# 2.837385 percent finished,count=517
# 009
# 2.842874 percent finished,count=518
# 009
# 2.848362 percent finished,count=519
# 009
# 2.853850 percent finished,count=520
# 009
# 2.859338 percent finished,count=521
# 009
# 2.864826 percent finished,count=522
# 009
# 2.870314 percent finished,count=523
# 009
# 2.875803 percent finished,count=524
# 009
# 2.881291 percent finished,count=525
# 009
# 2.886779 percent finished,count=526
# 009
# 2.892267 percent finished,count=527
# 009
# 2.897755 percent finished,count=528
# 009
# 2.903244 percent finished,count=529
# 009
# 2.908732 percent finished,count=530
# 009
# 2.914220 percent finished,count=531
# 009
# 2.919708 percent finished,count=532
# 009
# 2.925196 percent finished,count=533
# 009
# 2.930684 percent finished,count=534
# 009
# 2.936173 percent finished,count=535
# 009
# 2.941661 percent finished,count=536
# 009
# 2.947149 percent finished,count=537
# 009
# 2.952637 percent finished,count=538
# 009
# 2.958125 percent finished,count=539
# 009
# 2.963613 percent finished,count=540
# 009
# 2.969102 percent finished,count=541
# 009
# 2.974590 percent finished,count=542
# 009
# 2.980078 percent finished,count=543
# 009
# 2.985566 percent finished,count=544
# 009
# 2.991054 percent finished,count=545
# 009
# 2.996542 percent finished,count=546
# 009
# 3.002031 percent finished,count=547
# 009
# 3.007519 percent finished,count=548
# 009
# 3.013007 percent finished,count=549
# 009
# 3.018495 percent finished,count=550
# 009
# 3.023983 percent finished,count=551
# 009
# 3.029471 percent finished,count=552
# 009
# 3.034960 percent finished,count=553
# 009
# 3.040448 percent finished,count=554
# 009
# 3.045936 percent finished,count=555
# 009
# 3.051424 percent finished,count=556
# 009
# 3.056912 percent finished,count=557
# 009
# 3.062401 percent finished,count=558
# 009
# 3.067889 percent finished,count=559
# 009
# 3.073377 percent finished,count=560
# 009
# 3.078865 percent finished,count=561
# 009
# 3.084353 percent finished,count=562
# 009
# 3.089841 percent finished,count=563
# 009
# 3.095330 percent finished,count=564
# 009
# 3.100818 percent finished,count=565
# 009
# 3.106306 percent finished,count=566
# 009
# 3.111794 percent finished,count=567
# 009
# 3.117282 percent finished,count=568
# 009
# 3.122770 percent finished,count=569
# 010
# 3.128259 percent finished,count=570
# 010
# 3.133747 percent finished,count=571
# 010
# 3.139235 percent finished,count=572
# 010
# 3.144723 percent finished,count=573
# 010
# 3.150211 percent finished,count=574
# 010
# 3.155699 percent finished,count=575
# 010
# 3.161188 percent finished,count=576
# 010
# 3.166676 percent finished,count=577
# 010
# 3.172164 percent finished,count=578
# 010
# 3.177652 percent finished,count=579
# 010
# 3.183140 percent finished,count=580
# 010
# 3.188629 percent finished,count=581
# 010
# 3.194117 percent finished,count=582
# 010
# 3.199605 percent finished,count=583
# 010
# 3.205093 percent finished,count=584
# 010
# 3.210581 percent finished,count=585
# 010
# 3.216069 percent finished,count=586
# 010
# 3.221558 percent finished,count=587
# 010
# 3.227046 percent finished,count=588
# 010
# 3.232534 percent finished,count=589
# 010
# 3.238022 percent finished,count=590
# 010
# 3.243510 percent finished,count=591
# 010
# 3.248998 percent finished,count=592
# 010
# 3.254487 percent finished,count=593
# 010
# 3.259975 percent finished,count=594
# 010
# 3.265463 percent finished,count=595
# 010
# 3.270951 percent finished,count=596
# 010
# 3.276439 percent finished,count=597
# 010
# 3.281927 percent finished,count=598
# 010
# 3.287416 percent finished,count=599
# 010
# 3.292904 percent finished,count=600
# 010
# 3.298392 percent finished,count=601
# 010
# 3.303880 percent finished,count=602
# 010
# 3.309368 percent finished,count=603
# 010
# 3.314856 percent finished,count=604
# 010
# 3.320345 percent finished,count=605
# 010
# 3.325833 percent finished,count=606
# 010
# 3.331321 percent finished,count=607
# 010
# 3.336809 percent finished,count=608
# 010
# 3.342297 percent finished,count=609
# 010
# 3.347786 percent finished,count=610
# 010
# 3.353274 percent finished,count=611
# 010
# 3.358762 percent finished,count=612
# 010
# 3.364250 percent finished,count=613
# 010
# 3.369738 percent finished,count=614
# 010
# 3.375226 percent finished,count=615
# 010
# 3.380715 percent finished,count=616
# 010
# 3.386203 percent finished,count=617
# 010
# 3.391691 percent finished,count=618
# 010
# 3.397179 percent finished,count=619
# 010
# 3.402667 percent finished,count=620
# 011
# 3.408155 percent finished,count=621
# 011
# 3.413644 percent finished,count=622
# 011
# 3.419132 percent finished,count=623
# 011
# 3.424620 percent finished,count=624
# 011
# 3.430108 percent finished,count=625
# 011
# 3.435596 percent finished,count=626
# 011
# 3.441084 percent finished,count=627
# 011
# 3.446573 percent finished,count=628
# 011
# 3.452061 percent finished,count=629
# 011
# 3.457549 percent finished,count=630
# 011
# 3.463037 percent finished,count=631
# 011
# 3.468525 percent finished,count=632
# 011
# 3.474014 percent finished,count=633
# 011
# 3.479502 percent finished,count=634
# 011
# 3.484990 percent finished,count=635
# 011
# 3.490478 percent finished,count=636
# 011
# 3.495966 percent finished,count=637
# 011
# 3.501454 percent finished,count=638
# 011
# 3.506943 percent finished,count=639
# 011
# 3.512431 percent finished,count=640
# 011
# 3.517919 percent finished,count=641
# 011
# 3.523407 percent finished,count=642
# 011
# 3.528895 percent finished,count=643
# 011
# 3.534383 percent finished,count=644
# 011
# 3.539872 percent finished,count=645
# 011
# 3.545360 percent finished,count=646
# 011
# 3.550848 percent finished,count=647
# 011
# 3.556336 percent finished,count=648
# 011
# 3.561824 percent finished,count=649
# 011
# 3.567312 percent finished,count=650
# 011
# 3.572801 percent finished,count=651
# 011
# 3.578289 percent finished,count=652
# 011
# 3.583777 percent finished,count=653
# 011
# 3.589265 percent finished,count=654
# 011
# 3.594753 percent finished,count=655
# 011
# 3.600241 percent finished,count=656
# 011
# 3.605730 percent finished,count=657
# 011
# 3.611218 percent finished,count=658
# 011
# 3.616706 percent finished,count=659
# 011
# 3.622194 percent finished,count=660
# 011
# 3.627682 percent finished,count=661
# 011
# 3.633171 percent finished,count=662
# 012
# 3.638659 percent finished,count=663
# 012
# 3.644147 percent finished,count=664
# 012
# 3.649635 percent finished,count=665
# 012
# 3.655123 percent finished,count=666
# 012
# 3.660611 percent finished,count=667
# 012
# 3.666100 percent finished,count=668
# 012
# 3.671588 percent finished,count=669
# 012
# 3.677076 percent finished,count=670
# 012
# 3.682564 percent finished,count=671
# 012
# 3.688052 percent finished,count=672
# 012
# 3.693540 percent finished,count=673
# 012
# 3.699029 percent finished,count=674
# 012
# 3.704517 percent finished,count=675
# 012
# 3.710005 percent finished,count=676
# 012
# 3.715493 percent finished,count=677
# 012
# 3.720981 percent finished,count=678
# 012
# 3.726469 percent finished,count=679
# 012
# 3.731958 percent finished,count=680
# 012
# 3.737446 percent finished,count=681
# 012
# 3.742934 percent finished,count=682
# 012
# 3.748422 percent finished,count=683
# 012
# 3.753910 percent finished,count=684
# 012
# 3.759398 percent finished,count=685
# 012
# 3.764887 percent finished,count=686
# 012
# 3.770375 percent finished,count=687
# 012
# 3.775863 percent finished,count=688
# 012
# 3.781351 percent finished,count=689
# 012
# 3.786839 percent finished,count=690
# 012
# 3.792328 percent finished,count=691
# 012
# 3.797816 percent finished,count=692
# 012
# 3.803304 percent finished,count=693
# 012
# 3.808792 percent finished,count=694
# 012
# 3.814280 percent finished,count=695
# 012
# 3.819768 percent finished,count=696
# 012
# 3.825257 percent finished,count=697
# 012
# 3.830745 percent finished,count=698
# 012
# 3.836233 percent finished,count=699
# 012
# 3.841721 percent finished,count=700
# 012
# 3.847209 percent finished,count=701
# 012
# 3.852697 percent finished,count=702
# 012
# 3.858186 percent finished,count=703
# 012
# 3.863674 percent finished,count=704
# 012
# 3.869162 percent finished,count=705
# 012
# 3.874650 percent finished,count=706
# 012
# 3.880138 percent finished,count=707
# 012
# 3.885626 percent finished,count=708
# 012
# 3.891115 percent finished,count=709
# 012
# 3.896603 percent finished,count=710
# 012
# 3.902091 percent finished,count=711
# 012
# 3.907579 percent finished,count=712
# 012
# 3.913067 percent finished,count=713
# 012
# 3.918556 percent finished,count=714
# 012
# 3.924044 percent finished,count=715
# 012
# 3.929532 percent finished,count=716
# 012
# 3.935020 percent finished,count=717
# 012
# 3.940508 percent finished,count=718
# 012
# 3.945996 percent finished,count=719
# 013
# 3.951485 percent finished,count=720
# 013
# 3.956973 percent finished,count=721
# 013
# 3.962461 percent finished,count=722
# 013
# 3.967949 percent finished,count=723
# 013
# 3.973437 percent finished,count=724
# 013
# 3.978925 percent finished,count=725
# 013
# 3.984414 percent finished,count=726
# 013
# 3.989902 percent finished,count=727
# 013
# 3.995390 percent finished,count=728
# 013
# 4.000878 percent finished,count=729
# 013
# 4.006366 percent finished,count=730
# 013
# 4.011854 percent finished,count=731
# 013
# 4.017343 percent finished,count=732
# 013
# 4.022831 percent finished,count=733
# 013
# 4.028319 percent finished,count=734
# 013
# 4.033807 percent finished,count=735
# 013
# 4.039295 percent finished,count=736
# 013
# 4.044783 percent finished,count=737
# 013
# 4.050272 percent finished,count=738
# 013
# 4.055760 percent finished,count=739
# 013
# 4.061248 percent finished,count=740
# 013
# 4.066736 percent finished,count=741
# 013
# 4.072224 percent finished,count=742
# 013
# 4.077713 percent finished,count=743
# 013
# 4.083201 percent finished,count=744
# 013
# 4.088689 percent finished,count=745
# 013
# 4.094177 percent finished,count=746
# 013
# 4.099665 percent finished,count=747
# 013
# 4.105153 percent finished,count=748
# 013
# 4.110642 percent finished,count=749
# 013
# 4.116130 percent finished,count=750
# 013
# 4.121618 percent finished,count=751
# 013
# 4.127106 percent finished,count=752
# 013
# 4.132594 percent finished,count=753
# 013
# 4.138082 percent finished,count=754
# 013
# 4.143571 percent finished,count=755
# 013
# 4.149059 percent finished,count=756
# 013
# 4.154547 percent finished,count=757
# 013
# 4.160035 percent finished,count=758
# 013
# 4.165523 percent finished,count=759
# 013
# 4.171011 percent finished,count=760
# 013
# 4.176500 percent finished,count=761
# 013
# 4.181988 percent finished,count=762
# 013
# 4.187476 percent finished,count=763
# 013
# 4.192964 percent finished,count=764
# 013
# 4.198452 percent finished,count=765
# 013
# 4.203941 percent finished,count=766
# 013
# 4.209429 percent finished,count=767
# 013
# 4.214917 percent finished,count=768
# 013
# 4.220405 percent finished,count=769
# 013
# 4.225893 percent finished,count=770
# 013
# 4.231381 percent finished,count=771
# 013
# 4.236870 percent finished,count=772
# 013
# 4.242358 percent finished,count=773
# 013
# 4.247846 percent finished,count=774
# 014
# 4.253334 percent finished,count=775
# 014
# 4.258822 percent finished,count=776
# 014
# 4.264310 percent finished,count=777
# 014
# 4.269799 percent finished,count=778
# 014
# 4.275287 percent finished,count=779
# 014
# 4.280775 percent finished,count=780
# 014
# 4.286263 percent finished,count=781
# 014
# 4.291751 percent finished,count=782
# 014
# 4.297239 percent finished,count=783
# 014
# 4.302728 percent finished,count=784
# 014
# 4.308216 percent finished,count=785
# 014
# 4.313704 percent finished,count=786
# 014
# 4.319192 percent finished,count=787
# 014
# 4.324680 percent finished,count=788
# 014
# 4.330168 percent finished,count=789
# 014
# 4.335657 percent finished,count=790
# 014
# 4.341145 percent finished,count=791
# 014
# 4.346633 percent finished,count=792
# 014
# 4.352121 percent finished,count=793
# 014
# 4.357609 percent finished,count=794
# 014
# 4.363098 percent finished,count=795
# 014
# 4.368586 percent finished,count=796
# 014
# 4.374074 percent finished,count=797
# 014
# 4.379562 percent finished,count=798
# 014
# 4.385050 percent finished,count=799
# 014
# 4.390538 percent finished,count=800
# 014
# 4.396027 percent finished,count=801
# 014
# 4.401515 percent finished,count=802
# 014
# 4.407003 percent finished,count=803
# 014
# 4.412491 percent finished,count=804
# 014
# 4.417979 percent finished,count=805
# 014
# 4.423467 percent finished,count=806
# 014
# 4.428956 percent finished,count=807
# 014
# 4.434444 percent finished,count=808
# 014
# 4.439932 percent finished,count=809
# 014
# 4.445420 percent finished,count=810
# 014
# 4.450908 percent finished,count=811
# 014
# 4.456396 percent finished,count=812
# 014
# 4.461885 percent finished,count=813
# 014
# 4.467373 percent finished,count=814
# 014
# 4.472861 percent finished,count=815
# 014
# 4.478349 percent finished,count=816
# 015
# 4.483837 percent finished,count=817
# 015
# 4.489326 percent finished,count=818
# 015
# 4.494814 percent finished,count=819
# 015
# 4.500302 percent finished,count=820
# 015
# 4.505790 percent finished,count=821
# 015
# 4.511278 percent finished,count=822
# 015
# 4.516766 percent finished,count=823
# 015
# 4.522255 percent finished,count=824
# 015
# 4.527743 percent finished,count=825
# 015
# 4.533231 percent finished,count=826
# 015
# 4.538719 percent finished,count=827
# 015
# 4.544207 percent finished,count=828
# 015
# 4.549695 percent finished,count=829
# 015
# 4.555184 percent finished,count=830
# 015
# 4.560672 percent finished,count=831
# 015
# 4.566160 percent finished,count=832
# 015
# 4.571648 percent finished,count=833
# 015
# 4.577136 percent finished,count=834
# 015
# 4.582624 percent finished,count=835
# 015
# 4.588113 percent finished,count=836
# 015
# 4.593601 percent finished,count=837
# 015
# 4.599089 percent finished,count=838
# 015
# 4.604577 percent finished,count=839
# 015
# 4.610065 percent finished,count=840
# 015
# 4.615553 percent finished,count=841
# 015
# 4.621042 percent finished,count=842
# 015
# 4.626530 percent finished,count=843
# 015
# 4.632018 percent finished,count=844
# 015
# 4.637506 percent finished,count=845
# 015
# 4.642994 percent finished,count=846
# 015
# 4.648483 percent finished,count=847
# 015
# 4.653971 percent finished,count=848
# 015
# 4.659459 percent finished,count=849
# 015
# 4.664947 percent finished,count=850
# 015
# 4.670435 percent finished,count=851
# 015
# 4.675923 percent finished,count=852
# 015
# 4.681412 percent finished,count=853
# 015
# 4.686900 percent finished,count=854
# 015
# 4.692388 percent finished,count=855
# 015
# 4.697876 percent finished,count=856
# 015
# 4.703364 percent finished,count=857
# 015
# 4.708852 percent finished,count=858
# 015
# 4.714341 percent finished,count=859
# 015
# 4.719829 percent finished,count=860
# 015
# 4.725317 percent finished,count=861
# 015
# 4.730805 percent finished,count=862
# 015
# 4.736293 percent finished,count=863
# 015
# 4.741781 percent finished,count=864
# 015
# 4.747270 percent finished,count=865
# 015
# 4.752758 percent finished,count=866
# 015
# 4.758246 percent finished,count=867
# 015
# 4.763734 percent finished,count=868
# 015
# 4.769222 percent finished,count=869
# 015
# 4.774710 percent finished,count=870
# 015
# 4.780199 percent finished,count=871
# 015
# 4.785687 percent finished,count=872
# 015
# 4.791175 percent finished,count=873
# 016
# 4.796663 percent finished,count=874
# 016
# 4.802151 percent finished,count=875
# 016
# 4.807640 percent finished,count=876
# 016
# 4.813128 percent finished,count=877
# 016
# 4.818616 percent finished,count=878
# 016
# 4.824104 percent finished,count=879
# 016
# 4.829592 percent finished,count=880
# 016
# 4.835080 percent finished,count=881
# 016
# 4.840569 percent finished,count=882
# 016
# 4.846057 percent finished,count=883
# 016
# 4.851545 percent finished,count=884
# 016
# 4.857033 percent finished,count=885
# 016
# 4.862521 percent finished,count=886
# 016
# 4.868009 percent finished,count=887
# 016
# 4.873498 percent finished,count=888
# 016
# 4.878986 percent finished,count=889
# 016
# 4.884474 percent finished,count=890
# 016
# 4.889962 percent finished,count=891
# 016
# 4.895450 percent finished,count=892
# 016
# 4.900938 percent finished,count=893
# 016
# 4.906427 percent finished,count=894
# 016
# 4.911915 percent finished,count=895
# 016
# 4.917403 percent finished,count=896
# 016
# 4.922891 percent finished,count=897
# 016
# 4.928379 percent finished,count=898
# 016
# 4.933868 percent finished,count=899
# 016
# 4.939356 percent finished,count=900
# 016
# 4.944844 percent finished,count=901
# 016
# 4.950332 percent finished,count=902
# 016
# 4.955820 percent finished,count=903
# 016
# 4.961308 percent finished,count=904
# 016
# 4.966797 percent finished,count=905
# 016
# 4.972285 percent finished,count=906
# 016
# 4.977773 percent finished,count=907
# 016
# 4.983261 percent finished,count=908
# 016
# 4.988749 percent finished,count=909
# 016
# 4.994237 percent finished,count=910
# 016
# 4.999726 percent finished,count=911
# 016
# 5.005214 percent finished,count=912
# 016
# 5.010702 percent finished,count=913
# 016
# 5.016190 percent finished,count=914
# 016
# 5.021678 percent finished,count=915
# 016
# 5.027166 percent finished,count=916
# 016
# 5.032655 percent finished,count=917
# 016
# 5.038143 percent finished,count=918
# 016
# 5.043631 percent finished,count=919
# 016
# 5.049119 percent finished,count=920
# 016
# 5.054607 percent finished,count=921
# 016
# 5.060095 percent finished,count=922
# 016
# 5.065584 percent finished,count=923
# 016
# 5.071072 percent finished,count=924
# 017
# 5.076560 percent finished,count=925
# 017
# 5.082048 percent finished,count=926
# 017
# 5.087536 percent finished,count=927
# 017
# 5.093025 percent finished,count=928
# 017
# 5.098513 percent finished,count=929
# 017
# 5.104001 percent finished,count=930
# 017
# 5.109489 percent finished,count=931
# 017
# 5.114977 percent finished,count=932
# 017
# 5.120465 percent finished,count=933
# 017
# 5.125954 percent finished,count=934
# 017
# 5.131442 percent finished,count=935
# 017
# 5.136930 percent finished,count=936
# 017
# 5.142418 percent finished,count=937
# 017
# 5.147906 percent finished,count=938
# 017
# 5.153394 percent finished,count=939
# 017
# 5.158883 percent finished,count=940
# 017
# 5.164371 percent finished,count=941
# 017
# 5.169859 percent finished,count=942
# 017
# 5.175347 percent finished,count=943
# 017
# 5.180835 percent finished,count=944
# 017
# 5.186323 percent finished,count=945
# 017
# 5.191812 percent finished,count=946
# 017
# 5.197300 percent finished,count=947
# 017
# 5.202788 percent finished,count=948
# 017
# 5.208276 percent finished,count=949
# 017
# 5.213764 percent finished,count=950
# 017
# 5.219253 percent finished,count=951
# 017
# 5.224741 percent finished,count=952
# 017
# 5.230229 percent finished,count=953
# 017
# 5.235717 percent finished,count=954
# 017
# 5.241205 percent finished,count=955
# 017
# 5.246693 percent finished,count=956
# 017
# 5.252182 percent finished,count=957
# 017
# 5.257670 percent finished,count=958
# 017
# 5.263158 percent finished,count=959
# 017
# 5.268646 percent finished,count=960
# 017
# 5.274134 percent finished,count=961
# 017
# 5.279622 percent finished,count=962
# 017
# 5.285111 percent finished,count=963
# 017
# 5.290599 percent finished,count=964
# 017
# 5.296087 percent finished,count=965
# 017
# 5.301575 percent finished,count=966
# 017
# 5.307063 percent finished,count=967
# 017
# 5.312551 percent finished,count=968
# 018
# 5.318040 percent finished,count=969
# 018
# 5.323528 percent finished,count=970
# 018
# 5.329016 percent finished,count=971
# 018
# 5.334504 percent finished,count=972
# 018
# 5.339992 percent finished,count=973
# 018
# 5.345480 percent finished,count=974
# 018
# 5.350969 percent finished,count=975
# 018
# 5.356457 percent finished,count=976
# 018
# 5.361945 percent finished,count=977
# 018
# 5.367433 percent finished,count=978
# 018
# 5.372921 percent finished,count=979
# 018
# 5.378410 percent finished,count=980
# 018
# 5.383898 percent finished,count=981
# 018
# 5.389386 percent finished,count=982
# 018
# 5.394874 percent finished,count=983
# 018
# 5.400362 percent finished,count=984
# 018
# 5.405850 percent finished,count=985
# 018
# 5.411339 percent finished,count=986
# 018
# 5.416827 percent finished,count=987
# 018
# 5.422315 percent finished,count=988
# 018
# 5.427803 percent finished,count=989
# 018
# 5.433291 percent finished,count=990
# 018
# 5.438779 percent finished,count=991
# 018
# 5.444268 percent finished,count=992
# 018
# 5.449756 percent finished,count=993
# 018
# 5.455244 percent finished,count=994
# 018
# 5.460732 percent finished,count=995
# 018
# 5.466220 percent finished,count=996
# 018
# 5.471708 percent finished,count=997
# 018
# 5.477197 percent finished,count=998
# 018
# 5.482685 percent finished,count=999
# 018
# 5.488173 percent finished,count=1000
# 018
# 5.493661 percent finished,count=1001
# 018
# 5.499149 percent finished,count=1002
# 018
# 5.504638 percent finished,count=1003
# 018
# 5.510126 percent finished,count=1004
# 018
# 5.515614 percent finished,count=1005
# 018
# 5.521102 percent finished,count=1006
# 018
# 5.526590 percent finished,count=1007
# 018
# 5.532078 percent finished,count=1008
# 018
# 5.537567 percent finished,count=1009
# 018
# 5.543055 percent finished,count=1010
# 018
# 5.548543 percent finished,count=1011
# 018
# 5.554031 percent finished,count=1012
# 018
# 5.559519 percent finished,count=1013
# 018
# 5.565007 percent finished,count=1014
# 018
# 5.570496 percent finished,count=1015
# 018
# 5.575984 percent finished,count=1016
# 018
# 5.581472 percent finished,count=1017
# 018
# 5.586960 percent finished,count=1018
# 018
# 5.592448 percent finished,count=1019
# 018
# 5.597936 percent finished,count=1020
# 018
# 5.603425 percent finished,count=1021
# 019
# 5.608913 percent finished,count=1022
# 019
# 5.614401 percent finished,count=1023
# 019
# 5.619889 percent finished,count=1024
# 019
# 5.625377 percent finished,count=1025
# 019
# 5.630865 percent finished,count=1026
# 019
# 5.636354 percent finished,count=1027
# 019
# 5.641842 percent finished,count=1028
# 019
# 5.647330 percent finished,count=1029
# 019
# 5.652818 percent finished,count=1030
# 019
# 5.658306 percent finished,count=1031
# 019
# 5.663795 percent finished,count=1032
# 019
# 5.669283 percent finished,count=1033
# 019
# 5.674771 percent finished,count=1034
# 019
# 5.680259 percent finished,count=1035
# 019
# 5.685747 percent finished,count=1036
# 019
# 5.691235 percent finished,count=1037
# 019
# 5.696724 percent finished,count=1038
# 019
# 5.702212 percent finished,count=1039
# 019
# 5.707700 percent finished,count=1040
# 019
# 5.713188 percent finished,count=1041
# 019
# 5.718676 percent finished,count=1042
# 019
# 5.724164 percent finished,count=1043
# 019
# 5.729653 percent finished,count=1044
# 019
# 5.735141 percent finished,count=1045
# 019
# 5.740629 percent finished,count=1046
# 019
# 5.746117 percent finished,count=1047
# 019
# 5.751605 percent finished,count=1048
# 019
# 5.757093 percent finished,count=1049
# 019
# 5.762582 percent finished,count=1050
# 019
# 5.768070 percent finished,count=1051
# 019
# 5.773558 percent finished,count=1052
# 019
# 5.779046 percent finished,count=1053
# 019
# 5.784534 percent finished,count=1054
# 019
# 5.790023 percent finished,count=1055
# 019
# 5.795511 percent finished,count=1056
# 019
# 5.800999 percent finished,count=1057
# 019
# 5.806487 percent finished,count=1058
# 019
# 5.811975 percent finished,count=1059
# 019
# 5.817463 percent finished,count=1060
# 019
# 5.822952 percent finished,count=1061
# 019
# 5.828440 percent finished,count=1062
# 019
# 5.833928 percent finished,count=1063
# 019
# 5.839416 percent finished,count=1064
# 019
# 5.844904 percent finished,count=1065
# 019
# 5.850392 percent finished,count=1066
# 019
# 5.855881 percent finished,count=1067
# 019
# 5.861369 percent finished,count=1068
# 019
# 5.866857 percent finished,count=1069
# 019
# 5.872345 percent finished,count=1070
# 019
# 5.877833 percent finished,count=1071
# 019
# 5.883321 percent finished,count=1072
# 019
# 5.888810 percent finished,count=1073
# 019
# 5.894298 percent finished,count=1074
# 019
# 5.899786 percent finished,count=1075
# 019
# 5.905274 percent finished,count=1076
# 019
# 5.910762 percent finished,count=1077
# 019
# 5.916250 percent finished,count=1078
# 020
# 5.921739 percent finished,count=1079
# 020
# 5.927227 percent finished,count=1080
# 020
# 5.932715 percent finished,count=1081
# 020
# 5.938203 percent finished,count=1082
# 020
# 5.943691 percent finished,count=1083
# 020
# 5.949180 percent finished,count=1084
# 020
# 5.954668 percent finished,count=1085
# 020
# 5.960156 percent finished,count=1086
# 020
# 5.965644 percent finished,count=1087
# 020
# 5.971132 percent finished,count=1088
# 020
# 5.976620 percent finished,count=1089
# 020
# 5.982109 percent finished,count=1090
# 020
# 5.987597 percent finished,count=1091
# 020
# 5.993085 percent finished,count=1092
# 020
# 5.998573 percent finished,count=1093
# 020
# 6.004061 percent finished,count=1094
# 020
# 6.009549 percent finished,count=1095
# 020
# 6.015038 percent finished,count=1096
# 020
# 6.020526 percent finished,count=1097
# 020
# 6.026014 percent finished,count=1098
# 020
# 6.031502 percent finished,count=1099
# 020
# 6.036990 percent finished,count=1100
# 020
# 6.042478 percent finished,count=1101
# 020
# 6.047967 percent finished,count=1102
# 020
# 6.053455 percent finished,count=1103
# 020
# 6.058943 percent finished,count=1104
# 020
# 6.064431 percent finished,count=1105
# 020
# 6.069919 percent finished,count=1106
# 020
# 6.075407 percent finished,count=1107
# 020
# 6.080896 percent finished,count=1108
# 020
# 6.086384 percent finished,count=1109
# 020
# 6.091872 percent finished,count=1110
# 020
# 6.097360 percent finished,count=1111
# 020
# 6.102848 percent finished,count=1112
# 020
# 6.108337 percent finished,count=1113
# 020
# 6.113825 percent finished,count=1114
# 020
# 6.119313 percent finished,count=1115
# 020
# 6.124801 percent finished,count=1116
# 020
# 6.130289 percent finished,count=1117
# 020
# 6.135777 percent finished,count=1118
# 020
# 6.141266 percent finished,count=1119
# 020
# 6.146754 percent finished,count=1120
# 020
# 6.152242 percent finished,count=1121
# 020
# 6.157730 percent finished,count=1122
# 021
# 6.163218 percent finished,count=1123
# 021
# 6.168706 percent finished,count=1124
# 021
# 6.174195 percent finished,count=1125
# 021
# 6.179683 percent finished,count=1126
# 021
# 6.185171 percent finished,count=1127
# 021
# 6.190659 percent finished,count=1128
# 021
# 6.196147 percent finished,count=1129
# 021
# 6.201635 percent finished,count=1130
# 021
# 6.207124 percent finished,count=1131
# 021
# 6.212612 percent finished,count=1132
# 021
# 6.218100 percent finished,count=1133
# 021
# 6.223588 percent finished,count=1134
# 021
# 6.229076 percent finished,count=1135
# 021
# 6.234565 percent finished,count=1136
# 021
# 6.240053 percent finished,count=1137
# 021
# 6.245541 percent finished,count=1138
# 021
# 6.251029 percent finished,count=1139
# 021
# 6.256517 percent finished,count=1140
# 021
# 6.262005 percent finished,count=1141
# 021
# 6.267494 percent finished,count=1142
# 021
# 6.272982 percent finished,count=1143
# 021
# 6.278470 percent finished,count=1144
# 021
# 6.283958 percent finished,count=1145
# 021
# 6.289446 percent finished,count=1146
# 021
# 6.294934 percent finished,count=1147
# 021
# 6.300423 percent finished,count=1148
# 021
# 6.305911 percent finished,count=1149
# 021
# 6.311399 percent finished,count=1150
# 021
# 6.316887 percent finished,count=1151
# 021
# 6.322375 percent finished,count=1152
# 021
# 6.327863 percent finished,count=1153
# 021
# 6.333352 percent finished,count=1154
# 021
# 6.338840 percent finished,count=1155
# 021
# 6.344328 percent finished,count=1156
# 021
# 6.349816 percent finished,count=1157
# 021
# 6.355304 percent finished,count=1158
# 021
# 6.360792 percent finished,count=1159
# 021
# 6.366281 percent finished,count=1160
# 021
# 6.371769 percent finished,count=1161
# 021
# 6.377257 percent finished,count=1162
# 021
# 6.382745 percent finished,count=1163
# 021
# 6.388233 percent finished,count=1164
# 021
# 6.393722 percent finished,count=1165
# 021
# 6.399210 percent finished,count=1166
# 021
# 6.404698 percent finished,count=1167
# 021
# 6.410186 percent finished,count=1168
# 021
# 6.415674 percent finished,count=1169
# 021
# 6.421162 percent finished,count=1170
# 021
# 6.426651 percent finished,count=1171
# 021
# 6.432139 percent finished,count=1172
# 021
# 6.437627 percent finished,count=1173
# 021
# 6.443115 percent finished,count=1174
# 021
# 6.448603 percent finished,count=1175
# 022
# 6.454091 percent finished,count=1176
# 022
# 6.459580 percent finished,count=1177
# 022
# 6.465068 percent finished,count=1178
# 022
# 6.470556 percent finished,count=1179
# 022
# 6.476044 percent finished,count=1180
# 022
# 6.481532 percent finished,count=1181
# 022
# 6.487020 percent finished,count=1182
# 022
# 6.492509 percent finished,count=1183
# 022
# 6.497997 percent finished,count=1184
# 022
# 6.503485 percent finished,count=1185
# 022
# 6.508973 percent finished,count=1186
# 022
# 6.514461 percent finished,count=1187
# 022
# 6.519950 percent finished,count=1188
# 022
# 6.525438 percent finished,count=1189
# 022
# 6.530926 percent finished,count=1190
# 022
# 6.536414 percent finished,count=1191
# 022
# 6.541902 percent finished,count=1192
# 022
# 6.547390 percent finished,count=1193
# 022
# 6.552879 percent finished,count=1194
# 022
# 6.558367 percent finished,count=1195
# 022
# 6.563855 percent finished,count=1196
# 022
# 6.569343 percent finished,count=1197
# 022
# ...
# 97.963888 percent finished,count=17850
# 351
# 97.969376 percent finished,count=17851
# 351
# 97.974864 percent finished,count=17852
# 351
# 97.980352 percent finished,count=17853
# 351
# 97.985841 percent finished,count=17854
# 351
# 97.991329 percent finished,count=17855
# 351
# 97.996817 percent finished,count=17856
# 351
# 98.002305 percent finished,count=17857
# 351
# 98.007793 percent finished,count=17858
# 351
# 98.013281 percent finished,count=17859
# 351
# 98.018770 percent finished,count=17860
# 351
# 98.024258 percent finished,count=17861
# 351
# 98.029746 percent finished,count=17862
# 351
# 98.035234 percent finished,count=17863
# 351
# 98.040722 percent finished,count=17864
# 351
# 98.046210 percent finished,count=17865
# 351
# 98.051699 percent finished,count=17866
# 351
# 98.057187 percent finished,count=17867
# 351
# 98.062675 percent finished,count=17868
# 351
# 98.068163 percent finished,count=17869
# 351
# 98.073651 percent finished,count=17870
# 351
# 98.079139 percent finished,count=17871
# 352
# 98.084628 percent finished,count=17872
# 352
# 98.090116 percent finished,count=17873
# 352
# 98.095604 percent finished,count=17874
# 352
# 98.101092 percent finished,count=17875
# 352
# 98.106580 percent finished,count=17876
# 352
# 98.112068 percent finished,count=17877
# 352
# 98.117557 percent finished,count=17878
# 352
# 98.123045 percent finished,count=17879
# 352
# 98.128533 percent finished,count=17880
# 352
# 98.134021 percent finished,count=17881
# 352
# 98.139509 percent finished,count=17882
# 352
# 98.144998 percent finished,count=17883
# 352
# 98.150486 percent finished,count=17884
# 352
# 98.155974 percent finished,count=17885
# 352
# 98.161462 percent finished,count=17886
# 352
# 98.166950 percent finished,count=17887
# 352
# 98.172438 percent finished,count=17888
# 352
# 98.177927 percent finished,count=17889
# 352
# 98.183415 percent finished,count=17890
# 352
# 98.188903 percent finished,count=17891
# 352
# 98.194391 percent finished,count=17892
# 352
# 98.199879 percent finished,count=17893
# 352
# 98.205367 percent finished,count=17894
# 352
# 98.210856 percent finished,count=17895
# 352
# 98.216344 percent finished,count=17896
# 352
# 98.221832 percent finished,count=17897
# 352
# 98.227320 percent finished,count=17898
# 352
# 98.232808 percent finished,count=17899
# 352
# 98.238296 percent finished,count=17900
# 352
# 98.243785 percent finished,count=17901
# 352
# 98.249273 percent finished,count=17902
# 352
# 98.254761 percent finished,count=17903
# 352
# 98.260249 percent finished,count=17904
# 352
# 98.265737 percent finished,count=17905
# 352
# 98.271226 percent finished,count=17906
# 352
# 98.276714 percent finished,count=17907
# 352
# 98.282202 percent finished,count=17908
# 352
# 98.287690 percent finished,count=17909
# 352
# 98.293178 percent finished,count=17910
# 352
# 98.298666 percent finished,count=17911
# 352
# 98.304155 percent finished,count=17912
# 352
# 98.309643 percent finished,count=17913
# 352
# 98.315131 percent finished,count=17914
# 352
# 98.320619 percent finished,count=17915
# 352
# 98.326107 percent finished,count=17916
# 352
# 98.331595 percent finished,count=17917
# 352
# 98.337084 percent finished,count=17918
# 352
# 98.342572 percent finished,count=17919
# 352
# 98.348060 percent finished,count=17920
# 352
# 98.353548 percent finished,count=17921
# 352
# 98.359036 percent finished,count=17922
# 352
# 98.364524 percent finished,count=17923
# 352
# 98.370013 percent finished,count=17924
# 353
# 98.375501 percent finished,count=17925
# 353
# 98.380989 percent finished,count=17926
# 353
# 98.386477 percent finished,count=17927
# 353
# 98.391965 percent finished,count=17928
# 353
# 98.397453 percent finished,count=17929
# 353
# 98.402942 percent finished,count=17930
# 353
# 98.408430 percent finished,count=17931
# 353
# 98.413918 percent finished,count=17932
# 353
# 98.419406 percent finished,count=17933
# 353
# 98.424894 percent finished,count=17934
# 353
# 98.430383 percent finished,count=17935
# 353
# 98.435871 percent finished,count=17936
# 353
# 98.441359 percent finished,count=17937
# 353
# 98.446847 percent finished,count=17938
# 353
# 98.452335 percent finished,count=17939
# 353
# 98.457823 percent finished,count=17940
# 353
# 98.463312 percent finished,count=17941
# 353
# 98.468800 percent finished,count=17942
# 353
# 98.474288 percent finished,count=17943
# 353
# 98.479776 percent finished,count=17944
# 353
# 98.485264 percent finished,count=17945
# 353
# 98.490752 percent finished,count=17946
# 353
# 98.496241 percent finished,count=17947
# 353
# 98.501729 percent finished,count=17948
# 353
# 98.507217 percent finished,count=17949
# 353
# 98.512705 percent finished,count=17950
# 353
# 98.518193 percent finished,count=17951
# 353
# 98.523681 percent finished,count=17952
# 353
# 98.529170 percent finished,count=17953
# 353
# 98.534658 percent finished,count=17954
# 353
# 98.540146 percent finished,count=17955
# 353
# 98.545634 percent finished,count=17956
# 353
# 98.551122 percent finished,count=17957
# 353
# 98.556611 percent finished,count=17958
# 353
# 98.562099 percent finished,count=17959
# 353
# 98.567587 percent finished,count=17960
# 353
# 98.573075 percent finished,count=17961
# 353
# 98.578563 percent finished,count=17962
# 353
# 98.584051 percent finished,count=17963
# 353
# 98.589540 percent finished,count=17964
# 353
# 98.595028 percent finished,count=17965
# 353
# 98.600516 percent finished,count=17966
# 353
# 98.606004 percent finished,count=17967
# 353
# 98.611492 percent finished,count=17968
# 353
# 98.616980 percent finished,count=17969
# 353
# 98.622469 percent finished,count=17970
# 353
# 98.627957 percent finished,count=17971
# 353
# 98.633445 percent finished,count=17972
# 353
# 98.638933 percent finished,count=17973
# 353
# 98.644421 percent finished,count=17974
# 353
# 98.649909 percent finished,count=17975
# 353
# 98.655398 percent finished,count=17976
# 353
# 98.660886 percent finished,count=17977
# 353
# 98.666374 percent finished,count=17978
# 353
# 98.671862 percent finished,count=17979
# 353
# 98.677350 percent finished,count=17980
# 353
# 98.682838 percent finished,count=17981
# 353
# 98.688327 percent finished,count=17982
# 353
# 98.693815 percent finished,count=17983
# 353
# 98.699303 percent finished,count=17984
# 353
# 98.704791 percent finished,count=17985
# 354
# 98.710279 percent finished,count=17986
# 354
# 98.715768 percent finished,count=17987
# 354
# 98.721256 percent finished,count=17988
# 354
# 98.726744 percent finished,count=17989
# 354
# 98.732232 percent finished,count=17990
# 354
# 98.737720 percent finished,count=17991
# 354
# 98.743208 percent finished,count=17992
# 354
# 98.748697 percent finished,count=17993
# 354
# 98.754185 percent finished,count=17994
# 354
# 98.759673 percent finished,count=17995
# 354
# 98.765161 percent finished,count=17996
# 354
# 98.770649 percent finished,count=17997
# 354
# 98.776137 percent finished,count=17998
# 354
# 98.781626 percent finished,count=17999
# 354
# 98.787114 percent finished,count=18000
# 354
# 98.792602 percent finished,count=18001
# 354
# 98.798090 percent finished,count=18002
# 354
# 98.803578 percent finished,count=18003
# 354
# 98.809066 percent finished,count=18004
# 354
# 98.814555 percent finished,count=18005
# 354
# 98.820043 percent finished,count=18006
# 354
# 98.825531 percent finished,count=18007
# 354
# 98.831019 percent finished,count=18008
# 354
# 98.836507 percent finished,count=18009
# 354
# 98.841995 percent finished,count=18010
# 354
# 98.847484 percent finished,count=18011
# 354
# 98.852972 percent finished,count=18012
# 354
# 98.858460 percent finished,count=18013
# 354
# 98.863948 percent finished,count=18014
# 354
# 98.869436 percent finished,count=18015
# 354
# 98.874925 percent finished,count=18016
# 354
# 98.880413 percent finished,count=18017
# 354
# 98.885901 percent finished,count=18018
# 354
# 98.891389 percent finished,count=18019
# 355
# 98.896877 percent finished,count=18020
# 355
# 98.902365 percent finished,count=18021
# 355
# 98.907854 percent finished,count=18022
# 355
# 98.913342 percent finished,count=18023
# 355
# 98.918830 percent finished,count=18024
# 355
# 98.924318 percent finished,count=18025
# 355
# 98.929806 percent finished,count=18026
# 355
# 98.935294 percent finished,count=18027
# 355
# 98.940783 percent finished,count=18028
# 355
# 98.946271 percent finished,count=18029
# 355
# 98.951759 percent finished,count=18030
# 355
# 98.957247 percent finished,count=18031
# 355
# 98.962735 percent finished,count=18032
# 355
# 98.968223 percent finished,count=18033
# 355
# 98.973712 percent finished,count=18034
# 355
# 98.979200 percent finished,count=18035
# 355
# 98.984688 percent finished,count=18036
# 355
# 98.990176 percent finished,count=18037
# 355
# 98.995664 percent finished,count=18038
# 355
# 99.001153 percent finished,count=18039
# 355
# 99.006641 percent finished,count=18040
# 355
# 99.012129 percent finished,count=18041
# 355
# 99.017617 percent finished,count=18042
# 355
# 99.023105 percent finished,count=18043
# 355
# 99.028593 percent finished,count=18044
# 355
# 99.034082 percent finished,count=18045
# 355
# 99.039570 percent finished,count=18046
# 355
# 99.045058 percent finished,count=18047
# 355
# 99.050546 percent finished,count=18048
# 355
# 99.056034 percent finished,count=18049
# 355
# 99.061522 percent finished,count=18050
# 355
# 99.067011 percent finished,count=18051
# 355
# 99.072499 percent finished,count=18052
# 355
# 99.077987 percent finished,count=18053
# 355
# 99.083475 percent finished,count=18054
# 355
# 99.088963 percent finished,count=18055
# 355
# 99.094451 percent finished,count=18056
# 355
# 99.099940 percent finished,count=18057
# 355
# 99.105428 percent finished,count=18058
# 355
# 99.110916 percent finished,count=18059
# 355
# 99.116404 percent finished,count=18060
# 355
# 99.121892 percent finished,count=18061
# 355
# 99.127380 percent finished,count=18062
# 355
# 99.132869 percent finished,count=18063
# 355
# 99.138357 percent finished,count=18064
# 355
# 99.143845 percent finished,count=18065
# 355
# 99.149333 percent finished,count=18066
# 355
# 99.154821 percent finished,count=18067
# 355
# 99.160310 percent finished,count=18068
# 355
# 99.165798 percent finished,count=18069
# 355
# 99.171286 percent finished,count=18070
# 355
# 99.176774 percent finished,count=18071
# 355
# 99.182262 percent finished,count=18072
# 355
# 99.187750 percent finished,count=18073
# 355
# 99.193239 percent finished,count=18074
# 355
# 99.198727 percent finished,count=18075
# 355
# 99.204215 percent finished,count=18076
# 356
# 99.209703 percent finished,count=18077
# 356
# 99.215191 percent finished,count=18078
# 356
# 99.220679 percent finished,count=18079
# 356
# 99.226168 percent finished,count=18080
# 356
# 99.231656 percent finished,count=18081
# 356
# 99.237144 percent finished,count=18082
# 356
# 99.242632 percent finished,count=18083
# 356
# 99.248120 percent finished,count=18084
# 356
# 99.253608 percent finished,count=18085
# 356
# 99.259097 percent finished,count=18086
# 356
# 99.264585 percent finished,count=18087
# 356
# 99.270073 percent finished,count=18088
# 356
# 99.275561 percent finished,count=18089
# 356
# 99.281049 percent finished,count=18090
# 356
# 99.286538 percent finished,count=18091
# 356
# 99.292026 percent finished,count=18092
# 356
# 99.297514 percent finished,count=18093
# 356
# 99.303002 percent finished,count=18094
# 356
# 99.308490 percent finished,count=18095
# 356
# 99.313978 percent finished,count=18096
# 356
# 99.319467 percent finished,count=18097
# 356
# 99.324955 percent finished,count=18098
# 356
# 99.330443 percent finished,count=18099
# 356
# 99.335931 percent finished,count=18100
# 356
# 99.341419 percent finished,count=18101
# 356
# 99.346907 percent finished,count=18102
# 356
# 99.352396 percent finished,count=18103
# 356
# 99.357884 percent finished,count=18104
# 356
# 99.363372 percent finished,count=18105
# 356
# 99.368860 percent finished,count=18106
# 356
# 99.374348 percent finished,count=18107
# 356
# 99.379836 percent finished,count=18108
# 356
# 99.385325 percent finished,count=18109
# 356
# 99.390813 percent finished,count=18110
# 356
# 99.396301 percent finished,count=18111
# 356
# 99.401789 percent finished,count=18112
# 356
# 99.407277 percent finished,count=18113
# 356
# 99.412765 percent finished,count=18114
# 356
# 99.418254 percent finished,count=18115
# 356
# 99.423742 percent finished,count=18116
# 356
# 99.429230 percent finished,count=18117
# 356
# 99.434718 percent finished,count=18118
# 356
# 99.440206 percent finished,count=18119
# 356
# 99.445695 percent finished,count=18120
# 356
# 99.451183 percent finished,count=18121
# 356
# 99.456671 percent finished,count=18122
# 356
# 99.462159 percent finished,count=18123
# 356
# 99.467647 percent finished,count=18124
# 356
# 99.473135 percent finished,count=18125
# 356
# 99.478624 percent finished,count=18126
# 356
# 99.484112 percent finished,count=18127
# 356
# 99.489600 percent finished,count=18128
# 356
# 99.495088 percent finished,count=18129
# 356
# 99.500576 percent finished,count=18130
# 356
# 99.506064 percent finished,count=18131
# 356
# 99.511553 percent finished,count=18132
# 356
# 99.517041 percent finished,count=18133
# 356
# 99.522529 percent finished,count=18134
# 356
# 99.528017 percent finished,count=18135
# 356
# 99.533505 percent finished,count=18136
# 356
# 99.538993 percent finished,count=18137
# 356
# 99.544482 percent finished,count=18138
# 356
# 99.549970 percent finished,count=18139
# 356
# 99.555458 percent finished,count=18140
# 356
# 99.560946 percent finished,count=18141
# 357
# 99.566434 percent finished,count=18142
# 357
# 99.571923 percent finished,count=18143
# 357
# 99.577411 percent finished,count=18144
# 357
# 99.582899 percent finished,count=18145
# 357
# 99.588387 percent finished,count=18146
# 357
# 99.593875 percent finished,count=18147
# 357
# 99.599363 percent finished,count=18148
# 357
# 99.604852 percent finished,count=18149
# 357
# 99.610340 percent finished,count=18150
# 357
# 99.615828 percent finished,count=18151
# 357
# 99.621316 percent finished,count=18152
# 357
# 99.626804 percent finished,count=18153
# 357
# 99.632292 percent finished,count=18154
# 357
# 99.637781 percent finished,count=18155
# 357
# 99.643269 percent finished,count=18156
# 357
# 99.648757 percent finished,count=18157
# 357
# 99.654245 percent finished,count=18158
# 357
# 99.659733 percent finished,count=18159
# 357
# 99.665221 percent finished,count=18160
# 357
# 99.670710 percent finished,count=18161
# 357
# 99.676198 percent finished,count=18162
# 357
# 99.681686 percent finished,count=18163
# 357
# 99.687174 percent finished,count=18164
# 357
# 99.692662 percent finished,count=18165
# 357
# 99.698150 percent finished,count=18166
# 357
# 99.703639 percent finished,count=18167
# 358
# 99.709127 percent finished,count=18168
# 358
# 99.714615 percent finished,count=18169
# 358
# 99.720103 percent finished,count=18170
# 358
# 99.725591 percent finished,count=18171
# 358
# 99.731080 percent finished,count=18172
# 358
# 99.736568 percent finished,count=18173
# 358
# 99.742056 percent finished,count=18174
# 358
# 99.747544 percent finished,count=18175
# 358
# 99.753032 percent finished,count=18176
# 358
# 99.758520 percent finished,count=18177
# 358
# 99.764009 percent finished,count=18178
# 358
# 99.769497 percent finished,count=18179
# 358
# 99.774985 percent finished,count=18180
# 358
# 99.780473 percent finished,count=18181
# 358
# 99.785961 percent finished,count=18182
# 358
# 99.791449 percent finished,count=18183
# 358
# 99.796938 percent finished,count=18184
# 358
# 99.802426 percent finished,count=18185
# 358
# 99.807914 percent finished,count=18186
# 358
# 99.813402 percent finished,count=18187
# 358
# 99.818890 percent finished,count=18188
# 358
# 99.824378 percent finished,count=18189
# 358
# 99.829867 percent finished,count=18190
# 358
# 99.835355 percent finished,count=18191
# 358
# 99.840843 percent finished,count=18192
# 358
# 99.846331 percent finished,count=18193
# 358
# 99.851819 percent finished,count=18194
# 358
# 99.857308 percent finished,count=18195
# 358
# 99.862796 percent finished,count=18196
# 358
# 99.868284 percent finished,count=18197
# 358
# 99.873772 percent finished,count=18198
# 358
# 99.879260 percent finished,count=18199
# 358
# 99.884748 percent finished,count=18200
# 358
# 99.890237 percent finished,count=18201
# 358
# 99.895725 percent finished,count=18202
# 358
# 99.901213 percent finished,count=18203
# 358
# 99.906701 percent finished,count=18204
# 358
# 99.912189 percent finished,count=18205
# 358
# 99.917677 percent finished,count=18206
# 358
# 99.923166 percent finished,count=18207
# 358
# 99.928654 percent finished,count=18208
# 358
# 99.934142 percent finished,count=18209
# 358
# 99.939630 percent finished,count=18210
# 358
# 99.945118 percent finished,count=18211
# 358
# 99.950606 percent finished,count=18212
# 358
# 99.956095 percent finished,count=18213
# 358
# 99.961583 percent finished,count=18214
# 358
# 99.967071 percent finished,count=18215
# 358
# 99.972559 percent finished,count=18216
# 358
# 99.978047 percent finished,count=18217
# 358
# 99.983535 percent finished,count=18218
# 358
# 99.989024 percent finished,count=18219
# 358
# 99.994512 percent finished,count=18220
# 358
# 100.000000 percent finished,count=18221
# 358

# %%
while len(para_tables) > 10:
    para_tables = one_turn_concat(para_tables)
print(len(para_tables))
# Out:
# 9

# %%
for i in range(0,len(para_tables)):
    para_tables[i].to_csv('/data/project_unTimely_light_curve/total_catalogues/w1_w2_corelation_table_%d.csv'%(i))

# %%
import numpy as np
import os
for sub in np.arange(7,19,0.1):
    # os.mkdir('./total_catalogues/binned_new_var_paras/%.1f-%.1f'%(sub,sub+0.1))
    os.mkdir('./total_catalogues/binned_new_var_paras/%.1f-%.1f/w1'%(sub,sub+0.1))
    os.mkdir('./total_catalogues/binned_new_var_paras/%.1f-%.1f/w2'%(sub,sub+0.1))

# %%
import pandas as pd
import numpy as np
for i in range(10,19):
    w1_table = pd.read_csv('/data/project_unTimely_light_curve/total_catalogues/w1_new_var_para_table%d.csv'%i)
    w2_table = pd.read_csv('/data/project_unTimely_light_curve/total_catalogues/w2_new_var_para_table%d.csv'%i)
    for sub in np.arange(7,19,0.1):
        w1_sub_table = w1_table[(w1_table['Mean']>=sub) & (w1_table['Mean']<sub+0.1)]
        w2_sub_table = w2_table[(w2_table['Mean']>=sub) & (w2_table['Mean']<sub+0.1)]
        if len(w1_sub_table) != 0:
            w1_sub_table.to_csv('/data/project_unTimely_light_curve/total_catalogues/binned_new_var_paras/%.1f-%.1f/w1/table%d.csv'%(sub,sub+0.1,i))
        if len(w2_sub_table) != 0:
            w2_sub_table.to_csv('/data/project_unTimely_light_curve/total_catalogues/binned_new_var_paras/%.1f-%.1f/w2/table%d.csv'%(sub,sub+0.1,i))

# %%
sub=7
glob.glob('./total_catalogues/binned_new_var_paras/%.1f-%.1f/w2/*'%(sub,sub+0.1))
# Out:
# []

# %%
import glob
import pandas as pd
for sub in np.arange(7,19,0.1):
    for band in ['w1','w2']:
        para_tables = []
        name_list = glob.glob('/data/project_unTimely_light_curve/total_catalogues/binned_new_var_paras/%.1f-%.1f/%s/*'%(sub,sub+0.1,band))
        if len(name_list) > 0:
            for name in name_list:
                para_tables.append(pd.read_csv(name))
            while len(para_tables) > 1:
                para_tables[0] = pd.concat([para_tables[0],para_tables[1]],ignore_index=True)
                para_tables.pop(1)
            para_tables[0].to_csv('/data/project_unTimely_light_curve/total_catalogues/binned_new_var_paras/%.1f-%.1f/%s_total_paras.csv'%(sub,sub+0.1,band),index=False)

# %%
import pandas as pd
para_tables = []
for i in range(0,9):
    para_tables.append(pd.read_csv('/data/project_unTimely_light_curve/total_catalogues/w1_w2_corelation_table_%d.csv'%(i)))
while len(para_tables) > 1:
    para_tables[0] = pd.concat([para_tables[0],para_tables[1]],ignore_index=True)
    para_tables.pop(1)
para_tables[0].to_csv('/data/project_unTimely_light_curve/total_catalogues/w1_w2_corelation_totaltable.csv',index=False)
